# %% [markdown]
# ### 유가가 없는 데이터를 제거하고 pandas를 사용해 데이터를 정리해주세요
# 1) 셀프 주유소 여부에 따른 최소유가
#
# 2) 지역별 최소유가
#
# 3) 가장 유가가 저렴한 주유소, 비싼 주유소 5개씩

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
areas = [
    "강남구",
    "강동구",
    "강북구",
    "강서구",
    "관악구",
    "광진구",
    "구로구",
    "금천구",
    "노원구",
    "도봉구",
    "동대문구",
    "동작구",
    "마포구",
    "서대문구",
    "서초구",
    "성동구",
    "성북구",
    "송파구",
    "양천구",
    "영등포구",
    "용산구",
    "은평구",
    "종로구",
    "중구",
    "중랑구"
]

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}

session = requests.Session()
session.get('https://www.opinet.co.kr/user/main/mainView.do')

oil_station = []


for area in areas :

    data = {
        'BTN_DIV': 'os_btn',
    'BTN_DIV_STR': '',
    'POLL_ALL':'all',
    'SIDO_NM': '서울특별시',
    'SIGUNGU_NM': area,
    'SIDO_CD': 1,
    'SIGUN_CD':119,
    'MAP_CENTER_X':'', 
    'MAP_CENTER_Y': '',
    'MAP_ZOOM': '',
    'MAP_FIRST_X': '',
    'MAP_FIRST_Y': '',
    'LPG_YN':'' ,
    'SESSION_USER_ID':'' ,
    'SIDO_NM0':'서울특별시',
    'SIGUNGU_NM0': area,
    'DONG_NM': '',
    'GIS_X_COOR':'' ,
    'GIS_Y_COOR': '',
    'GIS_X_COOR_S':'' ,
    'GIS_X_COOR_E': '',
    'GIS_Y_COOR_S': '',
    'GIS_Y_COOR_E': '',
    'SEARCH_MOD': 'addr',
    'OS_NM': '',
    'OS_ADDR': '',
    'NORM_YN': 'on',
    'SELF_DIV_CD': 'on',
    'VLT_YN': 'on',
    'KPETRO_YN': 'on',
    'KPETRO_DP_YN': 'on',
    'POLL_DIV_CD': 'SKE',
    'POLL_DIV_CD': 'GSC',
    'POLL_DIV_CD': 'HDO',
    'POLL_DIV_CD': 'SOL',
    'POLL_DIV_CD': 'RTO',
    'POLL_DIV_CD': 'ETC',
    }



    response = session.post('https://www.opinet.co.kr/searRgSelect.do',data=data,headers=headers)

    soup = BeautifulSoup(response.text,'html.parser')



    for data in soup.select('table.tbl_type10 tbody#body1 >tr'):
        # print(data.select_one('a').attrs['href'])
        items = list(re.finditer("'[^']*',",data.select_one('a').attrs['href']))
        # 2-일반 휘발유 가격 (items[2].group())
        # 19- 셀프주유소 여부 
        # 22- 주유소 이름
        # 23 - 브랜드
        # 25 - 주소
        oil_station.append({
            '지역' : area,
            '유가' :items[2].group().replace("',","").replace("'",""),
            '주유소명':items[22].group().replace("',","").replace("'",""),
            '브랜드명' :items[23].group().replace("',","").replace("'",""),
            '주소' :items[25].group().replace("',","").replace("'",""),
            '셀프주유소여부':items[19].group().replace("',","").replace("'","")
        })


print(oil_station)
# Out:
# [{'지역': '강남구', '유가': '1583', '주유소명': '(주)보성 세곡주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구  헌릉로 731 (세곡동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1599', '주유소명': '현대오일뱅크(주)직영 산성셀프주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 헌릉로 730', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1629', '주유소명': '현대오일뱅크 도곡셀프주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구  남부순환로 2718 (도곡2동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1644', '주유소명': '오일프러스 셀프', '브랜드명': 'SK에너지', '주소': '서울 강남구 남부순환로 2651 (도곡동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1644', '주유소명': '현대오일뱅크(주) 유진주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 논현로 152 (도곡동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1665', '주유소명': 'SK서광주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 역삼로 142', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1667', '주유소명': '방죽주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 밤고개로 215 (율현동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1669', '주유소명': 'SK에너지(주) 매봉주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 언주로 307', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1669', '주유소명': 'SK에너지㈜ 진달래주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 도곡로 208', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1669', '주유소명': '에쓰-오일㈜직영 개나리주유소', '브랜드명': 'S-OIL', '주소': '서울 강남구 언주로 423 (역삼동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1675', '주유소명': '대교셀프주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 강남대로 640 (신사동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1689', '주유소명': '자곡셀프주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 밤고개로 120 (자곡동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1689', '주유소명': '(주)선진도곡주유소', '브랜드명': 'S-OIL', '주소': '서울 강남구 도곡로 162 (도곡동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1695', '주유소명': '(주)중앙에너비스 수서지점', '브랜드명': 'SK에너지', '주소': '서울 강남구 광평로 202 (수서동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1695', '주유소명': '일원주유소', '브랜드명': 'S-OIL', '주소': '서울 강남구 양재대로55길 3 (일원동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1737', '주유소명': '(유)동하석유 힐탑셀프주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 논현로 640', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1737', '주유소명': '대동석유 압구정주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 언주로 842 (신사동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '1848', '주유소명': '에스제이에너지산업(주) 개포주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 양재대로 339', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1863', '주유소명': '지에스칼텍스㈜에너지플러스허브GS타워', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 논현로 516 (역삼동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1929', '주유소명': '대성석유(주)동호주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 봉은사로113길 51', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1938', '주유소명': '현대오일뱅크(주)직영 신사현대주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 도산대로 163 (신사동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1976', '주유소명': '지에스칼텍스㈜ 은마주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 영동대로 235', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '1988', '주유소명': '현대오일뱅크(주)직영 한양주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 압구정로 302 (신사동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2062', '주유소명': '(주)소모에너지 쎈트럴주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 삼성로 335', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2062', '주유소명': '지에스칼텍스㈜ 삼성로주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 삼성로 563 (삼성동)', '셀프주유소여부': 'Y'}, {'지역': '강남구', '유가': '2093', '주유소명': '지에스칼텍스(주)학여울주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 남부순환로 3170 (일원2동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2098', '주유소명': '명품주유소', '브랜드명': 'S-OIL', '주소': '서울 강남구 도곡로 249 (역삼동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2188', '주유소명': '㈜새서울석유 새서울주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 압구정로 154', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2216', '주유소명': '대청주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 개포로 654 (일원동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2290', '주유소명': 'SK논현주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 논현로 747 (논현동)', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2290', '주유소명': '갤러리아주유소', '브랜드명': 'SK에너지', '주소': '서울 강남구 압구정로 426', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2298', '주유소명': '(주)새서울네트웍스 제이제이주유소', '브랜드명': '현대오일뱅크', '주소': '서울 강남구 언주로 716', '셀프주유소여부': 'N'}, {'지역': '강남구', '유가': '2578', '주유소명': '(주)만정에너지 삼보주유소', '브랜드명': 'GS칼텍스', '주소': '서울 강남구 봉은사로 433 (삼성동)', '셀프주유소여부': 'N'}, {'지역': '강동구', '유가': '1569', '주유소명': '재건에너지 재정제2주유소 고속셀프지점', '브랜드명': '현대오일뱅크', '주소': '서울특별시 강동구  천호대로 1246 (둔촌제2동)', '셀프주유소여부': 'Y'}, {'지역': '강동구', '유가': '1584', '주유소명': '구천면주유소', '브랜드명': '현대오일뱅크', '주소': ...

# %%
df = pd.DataFrame(oil_station)

# %%
df
# Out:
#       지역    유가                 주유소명    브랜드명                         주소 셀프주유소여부
# 0    강남구  1583          (주)보성 세곡주유소   SK에너지      서울 강남구  헌릉로 731 (세곡동)       Y
# 1    강남구  1599  현대오일뱅크(주)직영 산성셀프주유소  현대오일뱅크             서울 강남구 헌릉로 730       Y
# 2    강남구  1629       현대오일뱅크 도곡셀프주유소  현대오일뱅크  서울 강남구  남부순환로 2718 (도곡2동)       Y
# 3    강남구  1644             오일프러스 셀프   SK에너지    서울 강남구 남부순환로 2651 (도곡동)       Y
# 4    강남구  1644      현대오일뱅크(주) 유진주유소  현대오일뱅크       서울 강남구 논현로 152 (도곡동)       N
# ..   ...   ...                  ...     ...                        ...     ...
# 438  중랑구  1598              신일셀프주유소   SK에너지        서울 중랑구 상봉로 58 (망우동)       Y
# 439  중랑구  1598               용마로주유소   SK에너지      서울 중랑구 용마산로 309 (면목동)       Y
# 440  중랑구  1599                신내주유소   SK에너지      서울 중랑구 용마산로 705 (신내동)       Y
# 441  중랑구  1599             (주)기지에너지   S-OIL      서울 중랑구 용마산로 716 (신내동)       N
# 442  중랑구  1619                범아주유소   S-OIL        서울 중랑구 동일로 881 (묵동)       N
#
# [443 rows x 6 columns]

# %%
df['유가']
# Out:
# 0      1583
# 1      1599
# 2      1629
# 3      1644
# 4      1644
#        ...
# 438    1598
# 439    1598
# 440    1599
# 441    1599
# 442    1619
# Name: 유가, Length: 443, dtype: object

# %%
df['유가'] = df['유가'].astype('int64')

# %%
df['유가']
# Out:
# 0      1583
# 1      1599
# 2      1629
# 3      1644
# 4      1644
#        ...
# 438    1598
# 439    1598
# 440    1599
# 441    1599
# 442    1619
# Name: 유가, Length: 443, dtype: int64

# %%
df['유가'].isnull().sum()
# Out:
# 0

# %%
df.groupby('셀프주유소여부').min('유가')
# Out:
#            유가
# 셀프주유소여부
# N        1508
# Y        1494

# %%
df.groupby('지역').min('유가')
# Out:
#         유가
# 지역
# 강남구   1583
# 강동구   1569
# 강북구   1524
# 강서구   1508
# 관악구   1598
# 광진구   1554
# 구로구   1520
# 금천구   1555
# 노원구   1525
# 도봉구   1524
# 동대문구  1535
# 동작구   1560
# 마포구   1527
# 서대문구  1504
# 서초구   1514
# 성동구   1554
# 성북구   1523
# 송파구   1553
# 양천구   1508
# 영등포구  1517
# 용산구   1798
# 은평구   1494
# 종로구   1659
# 중구    1609
# 중랑구   1518

# %%
df.sort_values(by="유가").head(5)
# Out:
#        지역    유가             주유소명    브랜드명                    주소 셀프주유소여부
# 397   은평구  1494            응암주유소  현대오일뱅크        서울 은평구 응암로 163       Y
# 396   은평구  1494           타이거주유소   SK에너지  서울 은평구 수색로 188 (증산동)       Y
# 219  서대문구  1504       구도일주유소 두꺼비   S-OIL       서울 서대문구 성산로 312       Y
# 59    강서구  1508  이케이에너지(주) 강서주유소  현대오일뱅크  서울 강서구 화곡로 273 (화곡동)       Y
# 333   양천구  1508      플라트(주)서호주유소   GS칼텍스      서울 양천구 남부순환로 317       N

# %%
df.sort_values(by="유가",ascending= False).head(5)
# Out:
#       지역    유가                주유소명    브랜드명                     주소 셀프주유소여부
# 429   중구  2697               서남주유소   SK에너지           서울 중구 통일로 30       N
# 395  용산구  2695               서계주유소   GS칼텍스  서울 용산구  청파로 367 (청파동)       N
# 32   강남구  2578      (주)만정에너지 삼보주유소   GS칼텍스  서울 강남구 봉은사로 433 (삼성동)       N
# 428   중구  2449               필동주유소   GS칼텍스   서울 중구 퇴계로 196 (필동2가)       N
# 31   강남구  2298  (주)새서울네트웍스 제이제이주유소  현대오일뱅크         서울 강남구 언주로 716       N
